# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dataAA = np.loadtxt("./Bob/Bob_AA_1015.txt", comments='#')
dataAD = np.loadtxt("./Bob/Bob_AD_1015.txt", comments='#')
dataDA = np.loadtxt("./Bob/Bob_DA_1015.txt", comments='#')
dataDD = np.loadtxt("./Bob/Bob_DD_1015.txt", comments='#')
dataHH = np.loadtxt("./Bob/Bob_HH_1015.txt", comments='#')
dataHV = np.loadtxt("./Bob/Bob_HV_1015.txt", comments='#')
dataVH = np.loadtxt("./Bob/Bob_VH_1015.txt", comments='#')
dataVV = np.loadtxt("./Bob/Bob_VV_1015.txt", comments='#')

# %%
plt.plot(dataAA[:,0], dataAA[:,1], label="AA")
#plt.plot(dataAD[:,0], dataAD[:,1], label="AD")
#plt.plot(dataDA[:,0], dataDA[:,1], label="DA")
#plt.plot(dataDD[:,0], dataDD[:,1], label="DD")

plt.yticks([0, 50, 100, 150, 200])

plt.title("AA")
plt.xlabel("delay(ns)")
plt.ylabel("photon count(/10s)")

plt.savefig("./exp3.1-plots/AA.svg")

#plt.legend()

# %%
#plt.plot(dataAA[:,0], dataAA[:,1], label="AA")
plt.plot(dataAD[:,0], dataAD[:,1], label="AD")
#plt.plot(dataDA[:,0], dataDA[:,1], label="DA")
#plt.plot(dataDD[:,0], dataDD[:,1], label="DD")

plt.yticks([0, 50, 100, 150, 200])

plt.title("AD")
plt.xlabel("delay(ns)")
plt.ylabel("photon count(/10s)")

plt.savefig("./exp3.1-plots/AD.svg")

# %%
#plt.plot(dataAA[:,0], dataAA[:,1], label="AA")
#plt.plot(dataAD[:,0], dataAD[:,1], label="AD")
plt.plot(dataDA[:,0], dataDA[:,1], label="DA")
#plt.plot(dataDD[:,0], dataDD[:,1], label="DD")

plt.yticks([0, 50, 100, 150, 200])

plt.title("DA")
plt.xlabel("delay(ns)")
plt.ylabel("photon count(/10s)")

plt.savefig("./exp3.1-plots/DA.svg")

# %%
#plt.plot(dataAA[:,0], dataAA[:,1], label="AA")
#plt.plot(dataAD[:,0], dataAD[:,1], label="AD")
#plt.plot(dataDA[:,0], dataDA[:,1], label="DA")
plt.plot(dataDD[:,0], dataDD[:,1], label="DD")

plt.yticks([0, 50, 100, 150, 200])

plt.title("DD")
plt.xlabel("delay(ns)")
plt.ylabel("photon count(/10s)")

plt.savefig("./exp3.1-plots/DD.svg")

# %%
plt.plot(dataHH[:,0], dataHH[:,1], label="HH", color="orangered")

plt.yticks([0, 50, 100, 150, 200])

plt.title("HH")
plt.xlabel("delay(ns)")
plt.ylabel("photon count(/10s)")

plt.savefig("./exp3.1-plots/HH.svg")

# %%
plt.plot(dataHV[:,0], dataHV[:,1], label="HV", color="orangered")

plt.yticks([0, 50, 100, 150, 200])

plt.title("HV")
plt.xlabel("delay(ns)")
plt.ylabel("photon count(/10s)")

plt.savefig("./exp3.1-plots/HV.svg")

# %%
plt.plot(dataVH[:,0], dataVH[:,1], label="VH", color="orangered")

plt.yticks([0, 50, 100, 150, 200,250])

plt.title("VH")
plt.xlabel("delay(ns)")
plt.ylabel("photon count(/10s)")

plt.savefig("./exp3.1-plots/VH.svg")

# %%
plt.plot(dataVV[:,0], dataVV[:,1], label="VV", color="orangered")

plt.yticks([0, 50, 100, 150, 200])

plt.title("VV")
plt.xlabel("delay(ns)")
plt.ylabel("photon count(/10s)")

plt.savefig("./exp3.1-plots/VV.svg")
