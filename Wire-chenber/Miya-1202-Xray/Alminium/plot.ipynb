# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#ガス増幅率について

# テキストファイルの読み込み
file_path = 'combined_data.txt'

# 特定の行のデータを読み込む（3行目から6行目までを取得）
# header=Noneでヘッダーなしとして読み込む
data = pd.read_csv(file_path, delim_whitespace=True, header=None, comment='#')

# 表示したい特定の行をスライス（例：2行目から5行目まで）
selected_data = data.iloc[1]  # 0-indexedで3行目から6行目

# 表形式で表示
print("選択したデータ:")
print(selected_data)

# 偶数インデックスを y 値、奇数インデックスを誤差に分割
y_values = selected_data[::2]  # [386.009, 256.982]
y_errors = selected_data[1::2]  # [2.861, 2.401]

# x 座標
x_values = [1420, 1440, 1460, 1480, 1500]

# グラフのプロット
plt.figure(figsize=(8, 6))
plt.errorbar(x_values, y_values, yerr=y_errors, fmt='o', label='データ', capsize=5)
plt.yscale('log')  # y軸を対数スケールに設定
plt.xlabel('Voltage[V]')
plt.ylabel('gas Amplified rate[ch]')
plt.title('main peak HV-peak value')
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.xticks(np.arange(1420, 1520, 20))
# plt.legend()
plt.show()
# Out:
# 選択したデータ:
# 0     869.19869
# 1       0.29780
# 2     935.25020
# 3       0.33610
# 4    1016.74240
# 5       0.37940
# 6    1125.29810
# 7       0.49820
# 8    1239.67060
# 9       0.66920
# Name: 1, dtype: float64

# %%
#ガス増幅率について

# テキストファイルの読み込み
file_path = 'combined_data.txt'

# 特定の行のデータを読み込む（3行目から6行目までを取得）
# header=Noneでヘッダーなしとして読み込む
data = pd.read_csv(file_path, delim_whitespace=True, header=None, comment='#')

# 表示したい特定の行をスライス（例：2行目から5行目まで）
selected_data = data.iloc[3]  # 0-indexedで3行目から6行目

# 表形式で表示
print("選択したデータ:")
print(selected_data)

# 偶数インデックスを y 値、奇数インデックスを誤差に分割
y_values = selected_data[::2]  # [386.009, 256.982]
y_errors = selected_data[1::2]  # [2.861, 2.401]

# x 座標
x_values = [1420, 1440, 1460, 1480, 1500]

# グラフのプロット
plt.figure(figsize=(8, 6))
plt.errorbar(x_values, y_values, yerr=y_errors, fmt='o', label='データ', capsize=5)
# plt.xscale('log')  # y軸を対数スケールに設定
plt.yscale('log')  # y軸を対数スケールに設定
plt.xlabel('Voltage[V]')
plt.ylabel('Bunkaino')
plt.title('main peak HV-Bunkaino')
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.xticks(np.arange(1420, 1520, 20))
# plt.legend()
plt.show()
# Out:
# 選択したデータ:
# 0    11.953303
# 1     0.066204
# 2    11.775457
# 3     0.111998
# 4    13.254163
# 5     0.084287
# 6    14.500028
# 7     0.096787
# 8    15.938181
# 9     0.113824
# Name: 3, dtype: float64

# %%
#サブピークガス増幅率について

# テキストファイルの読み込み
file_path = 'combined_data.txt'

# 特定の行のデータを読み込む（3行目から6行目までを取得）
# header=Noneでヘッダーなしとして読み込む
data = pd.read_csv(file_path, delim_whitespace=True, header=None, comment='#')

# 表示したい特定の行をスライス（例：2行目から5行目まで）
selected_data = data.iloc[5]  # 0-indexedで3行目から6行目

# 表形式で表示
print("選択したデータ:")
print(selected_data)

# 偶数インデックスを y 値、奇数インデックスを誤差に分割
y_values = selected_data[::2]  # [386.009, 256.982]
y_errors = selected_data[1::2]  # [2.861, 2.401]

# x 座標
x_values = [1420, 1440, 1460, 1480, 1500]

# グラフのプロット
plt.figure(figsize=(8, 6))
plt.errorbar(x_values, y_values, yerr=y_errors, fmt='o', label='データ', capsize=5)
plt.yscale('log')  # y軸を対数スケールに設定
plt.xlabel('Voltage[V]')
plt.ylabel('gas Amplified rate[ch]')
plt.title('sub peak HV-peak value')
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.xticks(np.arange(1420, 1520, 20))
# plt.legend()
plt.show()
# Out:
# 選択したデータ:
# 0    758.352500
# 1      9.897000
# 2    780.270500
# 3      2.968000
# 4    820.341936
# 5      1.330000
# 6    877.827080
# 7      1.326000
# 8    936.451460
# 9      1.759000
# Name: 5, dtype: float64

# %%
#サブピークエネルギー分解能について

# テキストファイルの読み込み
file_path = 'combined_data.txt'

# 特定の行のデータを読み込む（3行目から6行目までを取得）
# header=Noneでヘッダーなしとして読み込む
data = pd.read_csv(file_path, delim_whitespace=True, header=None, comment='#')

# 表示したい特定の行をスライス（例：2行目から5行目まで）
selected_data = data.iloc[8]  # 0-indexedで3行目から6行目

# 表形式で表示
print("選択したデータ:")
print(selected_data)

# 偶数インデックスを y 値、奇数インデックスを誤差に分割
y_values = selected_data[::2]  # [386.009, 256.982]
y_errors = selected_data[1::2]  # [2.861, 2.401]

# x 座標
x_values = [1420, 1440, 1460, 1480, 1500]

# グラフのプロット
plt.figure(figsize=(8, 6))
plt.errorbar(x_values, y_values, yerr=y_errors, fmt='o', label='データ', capsize=5)
# plt.xscale('log')  # x軸を対数スケールに設定
plt.yscale('log')  # y軸を対数スケールに設定
plt.xlabel('Voltage[V]')
plt.ylabel('Bunkaino')
plt.title('sub peak HV-Bunkaino')
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.xticks(np.arange(1420, 1520, 20))
# plt.legend()
plt.show()
# Out:
# 選択したデータ:
# 0     5.805349
# 1     0.015216
# 2    10.876191
# 3     0.008678
# 4    11.995333
# 5     0.004898
# 6    14.162177
# 7     0.004287
# 8    16.782829
# 9     0.004543
# Name: 8, dtype: float64
